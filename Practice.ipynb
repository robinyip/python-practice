# %%
import pyodbc
import pandas as pd

cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=192.168.20.65;DATABASE=ais;UID=sa;PWD=gazette')
cursor = cnxn.cursor()
cursor.execute("SELECT dest FROM ais.dbo.vsl_routine where dest is not null")
rows = cursor.fetchall()
df = pd.DataFrame(rows)

# %%
df.columns = ['port']

# %%
#for x in range(len(df)):
#    df.port[x] = df.port[x][0]
df[:5]
# Out:
#                      port
# 0             [ZHENGJIAN]
# 1               [HUANGPU]
# 2  [THI:EAHSUNEAPTWET <(]
# 3                  [CORK]
# 4        [ROEDVIG-STEVNS]

# %%
import pyodbc
import pandas as pd

cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=192.168.20.65;DATABASE=ais;UID=sa;PWD=gazette')
sql = "SELECT dest FROM ais.dbo.vsl_routine where dest is not null"
data = pd.read_sql(sql, cnxn)

# %%
data[:5]
# Out:
#                    dest
# 0             ZHENGJIAN
# 1               HUANGPU
# 2  THI:EAHSUNEAPTWET <(
# 3                  CORK
# 4        ROEDVIG-STEVNS

# %%
data['dest'].value_counts()[:10]
# Out:
# ROTTERDAM    20008
# SINGAPORE    15669
# SHANGHAI      9906
# SHANG HAI     8619
# ANTWERP       8164
# AMSTERDAM     7724
# NINGBO        7379
# TIAN JIN      7365
# HAMBURG       6504
# HONGKONG      6132
# dtype: int64

# %%
a = data['dest'][:100]
b = pd.DataFrame( index=a, columns=a)

# %%
b
# Out:
# dest                 ZHENGJIAN HUANGPU THI:EAHSUNEAPTWET <( CORK  \
# dest
# ZHENGJIAN                  NaN     NaN                  NaN  NaN
# HUANGPU                    NaN     NaN                  NaN  NaN
# THI:EAHSUNEAPTWET <(       NaN     NaN                  NaN  NaN
# CORK                       NaN     NaN                  NaN  NaN
# ROEDVIG-STEVNS             NaN     NaN                  NaN  NaN
# HAMBURG                    NaN     NaN                  NaN  NaN
# CASABLANCA                 NaN     NaN                  NaN  NaN
# SINGAPORE                  NaN     NaN                  NaN  NaN
# KUCHING                    NaN     NaN                  NaN  NaN
# FISHING GROUND             NaN     NaN                  NaN  NaN
# FISHING                    NaN     NaN                  NaN  NaN
# GABES(TUNISIA)             NaN     NaN                  NaN  NaN
# SASSNITZ                   NaN     NaN                  NaN  NaN
# ...

# %%
from itertools import tee, imap, izip, combinations

def hammingDistance(str1, str2):
    return sum(imap(str.__ne__, str1, str2))

#b.apply( hammingDistance, axis=0)
for row in b.index:
    for col in b.columns:
        b.loc[row,col] = hammingDistance(row,col)

# %%
b
# Out:
# dest                 ZHENGJIAN HUANGPU THI:EAHSUNEAPTWET <( CORK  \
# dest
# ZHENGJIAN                    0       5                    8    4
# HUANGPU                      5       0                    7    4
# THI:EAHSUNEAPTWET <(         8       7                    0    4
# CORK                         4       4                    4    0
# ROEDVIG-STEVNS               8       7                   13    3
# HAMBURG                      7       6                    7    4
# CASABLANCA                   9       7                   10    3
# SINGAPORE                    9       6                    9    4
# KUCHING                      7       6                    7    4
# FISHING GROUND               9       7                   14    4
# FISHING                      7       7                    7    4
# GABES(TUNISIA)               8       7                   14    4
# SASSNITZ                     8       7                    8    4
# ...

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'],
#       dtype='|S10')
